# %%
import pyvista as pv

mesh = pv.read("wind_tunnel.vtk")
plotter = pv.Plotter()
plotter.add_mesh(mesh, show_edges=True, color="white")
plotter.show()
# Out:
# /Users/oliverpartridge/qiskit/anaconda3/envs/project_fisa_a1/lib/python3.13/site-packages/pyvista/jupyter/notebook.py:37: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
